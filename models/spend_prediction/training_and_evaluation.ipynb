# %% [markdown]
# # Spend Prediction Challenger Model
#
# This notebook trains and evaluates the spend prediction challenger model against a benchmark.

# %%
import pandas as pd
from models.spend_prediction.train import train_and_evaluate

features = pd.read_csv('../../data/output/account_features.csv')
metrics = train_and_evaluate(features)
metrics
